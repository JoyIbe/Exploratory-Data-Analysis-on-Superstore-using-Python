# %% [markdown]
# # Title: Superstore Sales Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_excel(r"C:\Users\IVANN\Downloads\Superstore 2014.xlsx")
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1         10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 2        172  CA-2014-118962 2014-08-05 2014-08-09  Standard Class
# 3        173  CA-2014-118962 2014-08-05 2014-08-09  Standard Class
# 4       1143  CA-2014-146969 2014-09-29 2014-10-03  Standard Class
# ...      ...             ...        ...        ...             ...
# 1988    9630  CA-2014-118192 2014-01-13 2014-01-18  Standard Class
# 1989    9712  CA-2014-114251 2014-11-05 2014-11-10  Standard Class
# 1990    9870  CA-2014-114195 2014-11-01 2014-11-03     First Class
# 1991    9871  CA-2014-114195 2014-11-01 2014-11-03     First Class
# 1992    9922  CA-2014-111360 2014-11-24 2014-11-30  Standard Class
#
#      Customer ID    Customer Name      Segment        Country          City  \
# 0       BH-11710  Brosina Hoffman     Consumer  United States   Los Angeles
# 1       BH-11710  Brosina Hoffman     Consumer  United States   Los Angeles
# 2       CS-12130     Chad Sievert     Consumer  United States   Los Angeles
# 3       CS-12130     Chad Sievert     Consumer  United States   Los Angeles
# 4       AP-10915   Arthur Prichep     Consumer  United States   Los Angeles
# ...          ...              ...          ...            ...           ...
# 1988    MM-17920    Michael Moore     Consumer  United States        Newark
# 1989    MD-17350    Maribeth Dona     Consumer  United States  Philadelphia
# 1990    EA-14035    Erin Ashbrook    Corporate  United States         Mason
# 1991    EA-14035    Erin Ashbrook    Corporate  United States         Mason
# 1992    AT-10435      Alyssa Tate  Home Office  United States         Akron
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...       90032    West  OFF-AR-10002833  Office Supplies          Art
# 1     ...       90032    West  OFF-AP-10002892  Office Supplies   Appliances
# 2     ...       90004    West  OFF-PA-10000659  Office Supplies        Paper
# 3     ...       90004    West  OFF-PA-10001144  Office Supplies        Paper
# 4     ...       90045    West  OFF-FA-10001561  Office Supplies    Fasteners
# ...   ...         ...     ...              ...              ...          ...
# 1988  ...       43055    East  OFF-BI-10003476  Office Supplies      Binders
# 1989  ...       19143    East  OFF-BI-10003684  Office Supplies      Binders
# 1990  ...       45040    East  OFF-BI-10000494  Office Supplies      Binders
# 1991  ...       45040    East  OFF-BI-10001658  Office Supplies      Binders
# 1992  ...       44312    East  OFF-BI-10003350  Office Supplies      Binders
#
#                                            Product Name    Sales  Quantity  \
# 0                                            Newell 322    7.280         4
# 1                      Belkin F5C206VTEL 6 Outlet Surge  114.900         5
# 2     Adams Phone Message Book, Professional, 400 Me...   20.940         3
# 3                                            Xerox 1913  110.960         2
# 4                                   Stockwell Push Pins    8.720         4
# ...                                                 ...      ...       ...
# 1988                        Avery Metallic Poly Binders    3.438         2
# 1989               Wilson Jones Legal Size Ring Binders   13.194         2
# 1990       Acco Economy Flexible Poly Round Ring Binder    3.132         2
# 1991                   GBC Standard Therm-A-Bind Covers   22.428         3
# 1992                    Acco Expandable Hanging Binders    5.742         3
#
#       Discount   Profit
# 0          0.0   1.9656
# 1          0.0  34.4700
# 2          0.0   9.8418
# 3          0.0  53.2608
# 4          0.0   2.8776
# ...        ...      ...
# 1988       0.7  -2.5212
# 1989       0.7  -8.7960
# 1990       0.7  -2.6100
# 1991       0.7 -17.9424
# 1992       0.7  -4.5936
#
# [1993 rows x 21 columns]

# %% [markdown]
# # Data Cleaning

# %%
# Checking for duplicates

df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Checking concise summary of the dataset for null values and correct datatypes

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1993 entries, 0 to 1992
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         1993 non-null   int64
#  1   Order ID       1993 non-null   object
#  2   Order Date     1993 non-null   datetime64[ns]
#  3   Ship Date      1993 non-null   datetime64[ns]
#  4   Ship Mode      1993 non-null   object
#  5   Customer ID    1993 non-null   object
#  6   Customer Name  1993 non-null   object
#  7   Segment        1993 non-null   object
#  8   Country        1993 non-null   object
#  9   City           1993 non-null   object
#  10  State          1993 non-null   object
#  11  Postal Code    1993 non-null   int64
#  12  Region         1993 non-null   object
#  13  Product ID     1993 non-null   object
#  14  Category       1993 non-null   object
#  15  Sub-Category   1993 non-null   object
#  16  Product Name   1993 non-null   object
#  17  Sales          1993 non-null   float64
#  18  Quantity       1993 non-null   int64
#  19  Discount       1993 non-null   float64
#  20  Profit         1993 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 327.1+ KB

# %%
# Datatype conversion

df['Row ID']=df['Row ID'].astype(object)
df['Row ID'].dtypes
# Out:
# dtype('O')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1993 entries, 0 to 1992
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         1993 non-null   object
#  1   Order ID       1993 non-null   object
#  2   Order Date     1993 non-null   datetime64[ns]
#  3   Ship Date      1993 non-null   datetime64[ns]
#  4   Ship Mode      1993 non-null   object
#  5   Customer ID    1993 non-null   object
#  6   Customer Name  1993 non-null   object
#  7   Segment        1993 non-null   object
#  8   Country        1993 non-null   object
#  9   City           1993 non-null   object
#  10  State          1993 non-null   object
#  11  Postal Code    1993 non-null   int64
#  12  Region         1993 non-null   object
#  13  Product ID     1993 non-null   object
#  14  Category       1993 non-null   object
#  15  Sub-Category   1993 non-null   object
#  16  Product Name   1993 non-null   object
#  17  Sales          1993 non-null   float64
#  18  Quantity       1993 non-null   int64
#  19  Discount       1993 non-null   float64
#  20  Profit         1993 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(2), object(14)
# memory usage: 327.1+ KB

# %% [markdown]
# # Exploration

# %% [markdown]
# ## Analyzing Sales Performance

# %%
#Calculate Total Sales and Total Quantity Sold.

total_sales = np.sum(df['Sales'])  # Total Sales

print(f'Total Sales: {total_sales}')
# Out:
# Total Sales: 484247.49809999997

# %%
total_quantity = np.sum(df['Quantity'])     # Total Quantity

print(f'Total Quantity: {total_quantity}')
# Out:
# Total Quantity: 7581

# %%
# Identify the Top 5 Best-Selling Products by Total Sales.

df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(5)
# Out:
# Product Name
# Cisco TelePresence System EX90 Videoconferencing Unit        22638.480
# Lexmark MX611dhe Monochrome Laser Printer                    11219.934
# HP Designjet T520 Inkjet Large Format Printer - 24" Color     9624.945
# Ibico EPK-21 Electric Binding System                          9449.950
# High Speed Automatic Electric Letter Opener                   8187.650
# Name: Sales, dtype: float64

# %%
# Viz

import warnings
warnings.filterwarnings('ignore')

products = df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(5)
plt.figure(figsize=(15, 8))

plot = sns.barplot(data=products, palette=sns.color_palette('tab10'))
for bars in plot.containers:
    plot.bar_label(bars, [f'{x:.2f}' for x in bars.datavalues])
plot.set_xlabel('Products')
plot.set_ylabel('Total Sales')   
plt.title('Top Best-Selling Products by Revenue')
plt.xticks(rotation=80, ha='right')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Determine the Region with the Highest Revenue.

df.groupby('Region')['Sales'].sum().sort_values(ascending=False)
# Out:
# Region
# West       147883.0330
# East       128680.4570
# South      103845.8435
# Central    103838.1646
# Name: Sales, dtype: float64

# %%
# Viz

region =df.groupby('Region')['Sales'].sum().sort_values(ascending=False)

plt.bar(region.index, region.values)
for i, value in enumerate(region.values):
    plt.text(i, value, f'{value}', ha='center', va='bottom')
    
plt.xlabel('Region')
plt.ylabel('Sales(Revenue)')
plt.title('Revenue by Region ', fontsize=15)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1993 entries, 0 to 1992
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         1993 non-null   object
#  1   Order ID       1993 non-null   object
#  2   Order Date     1993 non-null   datetime64[ns]
#  3   Ship Date      1993 non-null   datetime64[ns]
#  4   Ship Mode      1993 non-null   object
#  5   Customer ID    1993 non-null   object
#  6   Customer Name  1993 non-null   object
#  7   Segment        1993 non-null   object
#  8   Country        1993 non-null   object
#  9   City           1993 non-null   object
#  10  State          1993 non-null   object
#  11  Postal Code    1993 non-null   int64
#  12  Region         1993 non-null   object
#  13  Product ID     1993 non-null   object
#  14  Category       1993 non-null   object
#  15  Sub-Category   1993 non-null   object
#  16  Product Name   1993 non-null   object
#  17  Sales          1993 non-null   float64
#  18  Quantity       1993 non-null   int64
#  19  Discount       1993 non-null   float64
#  20  Profit         1993 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(2), object(14)
# memory usage: 327.1+ KB

# %%
# Analyze monthly sales trends — which months have the highest and lowest sales?

df['Month'] = df['Order Date'].dt.strftime('%b')  # Extract month as abbreviated name, adding new month column
df['Year'] = df['Order Date'].dt.year  # Extract year and add to new columns
df
# Out:
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0         7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 1        10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 2       172  CA-2014-118962 2014-08-05 2014-08-09  Standard Class    CS-12130
# 3       173  CA-2014-118962 2014-08-05 2014-08-09  Standard Class    CS-12130
# 4      1143  CA-2014-146969 2014-09-29 2014-10-03  Standard Class    AP-10915
# ...     ...             ...        ...        ...             ...         ...
# 1988   9630  CA-2014-118192 2014-01-13 2014-01-18  Standard Class    MM-17920
# 1989   9712  CA-2014-114251 2014-11-05 2014-11-10  Standard Class    MD-17350
# 1990   9870  CA-2014-114195 2014-11-01 2014-11-03     First Class    EA-14035
# 1991   9871  CA-2014-114195 2014-11-01 2014-11-03     First Class    EA-14035
# 1992   9922  CA-2014-111360 2014-11-24 2014-11-30  Standard Class    AT-10435
#
#         Customer Name      Segment        Country          City  ...  \
# 0     Brosina Hoffman     Consumer  United States   Los Angeles  ...
# 1     Brosina Hoffman     Consumer  United States   Los Angeles  ...
# 2        Chad Sievert     Consumer  United States   Los Angeles  ...
# 3        Chad Sievert     Consumer  United States   Los Angeles  ...
# 4      Arthur Prichep     Consumer  United States   Los Angeles  ...
# ...               ...          ...            ...           ...  ...
# 1988    Michael Moore     Consumer  United States        Newark  ...
# 1989    Maribeth Dona     Consumer  United States  Philadelphia  ...
# 1990    Erin Ashbrook    Corporate  United States         Mason  ...
# 1991    Erin Ashbrook    Corporate  United States         Mason  ...
# 1992      Alyssa Tate  Home Office  United States         Akron  ...
#
#            Product ID         Category Sub-Category  \
# 0     OFF-AR-10002833  Office Supplies          Art
# 1     OFF-AP-10002892  Office Supplies   Appliances
# 2     OFF-PA-10000659  Office Supplies        Paper
# 3     OFF-PA-10001144  Office Supplies        Paper
# 4     OFF-FA-10001561  Office Supplies    Fasteners
# ...               ...              ...          ...
# 1988  OFF-BI-10003476  Office Supplies      Binders
# 1989  OFF-BI-10003684  Office Supplies      Binders
# 1990  OFF-BI-10000494  Office Supplies      Binders
# 1991  OFF-BI-10001658  Office Supplies      Binders
# 1992  OFF-BI-10003350  Office Supplies      Binders
#
#                                            Product Name    Sales Quantity  \
# 0                                            Newell 322    7.280        4
# 1                      Belkin F5C206VTEL 6 Outlet Surge  114.900        5
# 2     Adams Phone Message Book, Professional, 400 Me...   20.940        3
# 3                                            Xerox 1913  110.960        2
# 4                                   Stockwell Push Pins    8.720        4
# ...                                                 ...      ...      ...
# 1988                        Avery Metallic Poly Binders    3.438        2
# 1989               Wilson Jones Legal Size Ring Binders   13.194        2
# 1990       Acco Economy Flexible Poly Round Ring Binder    3.132        2
# 1991                   GBC Standard Therm-A-Bind Covers   22.428        3
# 1992                    Acco Expandable Hanging Binders    5.742        3
#
#      Discount   Profit  Month  Year
# 0         0.0   1.9656    Jun  2014
# 1         0.0  34.4700    Jun  2014
# 2         0.0   9.8418    Aug  2014
# 3         0.0  53.2608    Aug  2014
# 4         0.0   2.8776    Sep  2014
# ...       ...      ...    ...   ...
# 1988      0.7  -2.5212    Jan  2014
# 1989      0.7  -8.7960    Nov  2014
# 1990      0.7  -2.6100    Nov  2014
# 1991      0.7 -17.9424    Nov  2014
# 1992      0.7  -4.5936    Nov  2014
#
# [1993 rows x 23 columns]

# %%
# Monthly Sales Trend Viz

monthly_revenue = df.groupby(['Year', 'Month'])['Sales'].sum().reset_index()

plt.figure(figsize=(20, 5))
sns.lineplot(x='Month', y='Sales', hue='Year', data=monthly_revenue, marker='o')

plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.title('Monthly Sales Trend')
plt.legend(title='Year')
plt.show()

# %%
# Identifying sales spike in product category

monthly_revenue = df.groupby(['Year', 'Month', 'Category'])['Sales'].sum().reset_index()

plt.figure(figsize=(20, 5))
sns.lineplot(x='Month', y='Sales', hue='Year', style='Category', palette='tab10', data=monthly_revenue, marker='o')

plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.title('Monthly Sales Trend by Category')
plt.legend(title='Year and Category', loc='best')
plt.show()
